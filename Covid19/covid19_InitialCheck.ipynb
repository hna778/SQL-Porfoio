# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'/Users/hna/Documents/DA/SQL/Covid19/covid19.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530292 entries, 0 to 530291
# Data columns (total 61 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   country                                     530292 non-null  object
#  1   date                                        530292 non-null  object
#  2   total_cases                                 516426 non-null  float64
#  3   new_cases                                   513144 non-null  float64
#  4   new_cases_smoothed                          511939 non-null  float64
#  5   total_cases_per_million                     516426 non-null  float64
#  6   new_cases_per_million                       513144 non-null  float64
#  7   new_cases_smoothed_per_million              511939 non-null  float64
#  8   total_deaths                                516426 non-null  float64
# ...

# %%
df.head()
# Out:
#        country        date  total_cases  new_cases  new_cases_smoothed  \
# 0  Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1  Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2  Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3  Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4  Afghanistan  2020-01-05          0.0        0.0                 NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      0.0                    0.0
# 4                      0.0                    0.0
#
#    new_cases_smoothed_per_million  total_deaths  new_deaths  ...  population  \
# 0                             NaN           NaN         NaN  ...  40578847.0
# 1                             NaN           NaN         NaN  ...  40578847.0
# ...

# %%
df.isnull().sum()
# Out:
# country                            0
# date                               0
# total_cases                    13866
# new_cases                      17148
# new_cases_smoothed             18353
#                                ...
# extreme_poverty               190395
# diabetes_prevalence            82901
# handwashing_facilities        290110
# hospital_beds_per_thousand    209535
# human_development_index       530292
# Length: 61, dtype: int64

# %%
df_export = df[['code', 'continent', 'country', 'date', 'population', 'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 
'new_deaths', 'new_deaths_smoothed', 'total_vaccinations', 'people_vaccinated']]
df_export
# Out:
#        code continent      country        date  population  total_cases  \
# 0       AFG      Asia  Afghanistan  2020-01-01  40578847.0          NaN
# 1       AFG      Asia  Afghanistan  2020-01-02  40578847.0          NaN
# 2       AFG      Asia  Afghanistan  2020-01-03  40578847.0          NaN
# 3       AFG      Asia  Afghanistan  2020-01-04  40578847.0          0.0
# 4       AFG      Asia  Afghanistan  2020-01-05  40578847.0          0.0
# ...     ...       ...          ...         ...         ...          ...
# 530287  ZWE    Africa     Zimbabwe  2025-09-03  16069061.0     266434.0
# 530288  ZWE    Africa     Zimbabwe  2025-09-04  16069061.0     266434.0
# 530289  ZWE    Africa     Zimbabwe  2025-09-05  16069061.0     266434.0
# 530290  ZWE    Africa     Zimbabwe  2025-09-06  16069061.0     266434.0
# 530291  ZWE    Africa     Zimbabwe  2025-09-07  16069061.0     266434.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df_export.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530292 entries, 0 to 530291
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   code                 507044 non-null  object
#  1   continent            490452 non-null  object
#  2   country              530292 non-null  object
#  3   date                 530292 non-null  object
#  4   population           513194 non-null  float64
#  5   total_cases          516426 non-null  float64
#  6   new_cases            513144 non-null  float64
#  7   new_cases_smoothed   511939 non-null  float64
#  8   total_deaths         516426 non-null  float64
#  9   new_deaths           514015 non-null  float64
#  10  new_deaths_smoothed  512803 non-null  float64
#  11  total_vaccinations   83222 non-null   float64
#  12  people_vaccinated    79011 non-null   float64
# dtypes: float64(9), object(4)
# memory usage: 52.6+ MB

# %%
df_export.to_csv(r'/Users/hna/Documents/DA/SQL/Covid19/covid19_export.csv', index=False)
